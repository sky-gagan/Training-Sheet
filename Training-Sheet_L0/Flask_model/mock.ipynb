# %%
import pandas as pd

# %%
df = pd.read_csv('final1.csv')
df.head()
# Out:
#    Unnamed: 0  engineTransmission_battery_value  \
# 0           0                                 0
# 1           1                                 1
# 2           2                                 1
# 3           3                                 1
# 4           4                                 1
#
#    engineTransmission_engineoilLevelDipstick_value  \
# 0                                                1
# 1                                                1
# 2                                                1
# 3                                                1
# 4                                                1
#
#    engineTransmission_engineOil  engineTransmission_engineOil_cc_value_0  \
# 0                             0                                        5
# 1                             0                                        5
# 2                             0                                        0
# ...

# %%
class_labels = {5.0 : 1, 4.5 : 2, 4.0 : 3, 3.5 : 4, 3.0 : 5, 2.5 : 6, 2.0 : 7,
                1.5 : 8, 1.0 : 9, 0.5 : 10}

# %%
[class_ for class_,label in class_labels.items() if label == 8][0]
# Out:
# 1.5

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score
import pickle

df1 = pd.read_csv('final1.csv')
df1.drop(columns='Unnamed: 0',inplace=True)
X = df1.drop(columns = ['rating_engineTransmission'])
Y = df1['rating_engineTransmission']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.33)

# %%
X_train
# Out:
#        engineTransmission_battery_value  \
# 21269                                 1
# 2569                                  1
# 4088                                  0
# 9549                                  1
# 23049                                 1
# ...                                 ...
# 26070                                 0
# 14215                                 1
# 25260                                 1
# 3076                                  1
# 1573                                  1
#
#        engineTransmission_engineoilLevelDipstick_value  \
# 21269                                                1
# 2569                                                 1
# 4088                                                 1
# 9549                                                 0
# 23049                                                1
# ...                                                ...
# 26070                                                1
# ...
